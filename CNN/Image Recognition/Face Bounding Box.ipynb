# %%
import cv2
import matplotlib.pyplot as plt

print(cv2.__version__)
# Out:
# 4.1.2

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml -O /content/face.xml
# Out:
# --2020-09-19 07:02:55--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘/content/face.xml’
#
# /content/face.xml   100%[===================>] 908.33K  --.-KB/s    in 0.06s
#
# 2020-09-19 07:02:55 (14.5 MB/s) - ‘/content/face.xml’ saved [930127/930127]

# %%
pixels = imread('test1.jpg')
# load the pre-trained model
classifier = CascadeClassifier('haarcascade_frontalface_default.xml')
# perform face detection
bboxes = classifier.detectMultiScale(pixels)
# print bounding box for each detected face
for box in bboxes:
	# extract
	x, y, width, height = box
	x2, y2 = x + width, y + height
	# draw a rectangle over the pixels
	rectangle(pixels, (x, y), (x2, y2), (0,0,255), 1)
# show the image
imshow('face detection', pixels)
# keep the window open until we press a key
waitKey(0)
# close the window
destroyAllWindows()

# %%
from google.colab.patches import cv2_imshow
clf = cv2.CascadeClassifier('face.xml')

# %%
img_arr = cv2.imread('ff2.png')

#Get the bounding boxes of the detected faces
bboxes = clf.detectMultiScale(img_arr)

for box in bboxes:
  x, y, width, height = box
  x2, y2 = x+width, y+height
  #Draw a rectangle (Using the bounding box coordinates), indicating the rgb value of the rectangle and its thickness
  cv2.rectangle(img_arr, (x,y), (x2,y2), (0,0,255), 1)

cv2_imshow(img_arr)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x685 at 0x7F3EBA301BA8>

# %%
# !pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 42kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566173 sha256=994f4880e330d7e13fdfca2279a211b9968c37f8e4a072d652ed4d9772392b2f
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
import face_recognition
