# %%
# !git clone https://github.com/nicknochnack/RealTimeObjectDetection
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'RealTimeObjectDetection' already exists and is not an empty directory.
# Cloning into 'labelImg'...
# remote: Enumerating objects: 1836, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 1836 (delta 30), reused 52 (delta 17), pack-reused 1759
# Receiving objects: 100% (1836/1836), 232.81 MiB | 52.72 MiB/s, done.
# Resolving deltas: 100% (1077/1077), done.

# %%
# !pip install PyQt5
# !pip install lxml
# Out:
# Requirement already satisfied: PyQt5 in /usr/local/lib/python3.7/dist-packages (5.15.4)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in /usr/local/lib/python3.7/dist-packages (from PyQt5) (12.9.0)
# Requirement already satisfied: PyQt5-Qt5>=5.15 in /usr/local/lib/python3.7/dist-packages (from PyQt5) (5.15.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (4.2.6)
