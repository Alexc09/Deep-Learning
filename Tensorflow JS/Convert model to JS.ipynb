# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
x = np.array([1.0,4.0,6.0,2.0,5.0],dtype=float)
y = np.array([3.0,6.0,8.0,4.0,7.0],dtype=float)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1,input_shape=[1]))

# %%
model.compile(loss='mean_squared_error',optimizer='sgd')

# %%
model.fit(x,y,epochs=2000,verbose=1)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1537
# Epoch 2/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1525
# Epoch 3/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1513
# Epoch 4/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1501
# Epoch 5/2000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1489
# Epoch 6/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1477
# Epoch 7/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1465
# Epoch 8/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1453
# Epoch 9/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1442
# Epoch 10/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1430
# Epoch 11/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1419
# Epoch 12/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1408
# ...

# %%
model.predict([9.0])
# Out:
# array([[11.000284]], dtype=float32)

# %%
save_path = '/content/model'
model.save(save_path)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /content/model/assets

# %%
#Get the .json and the .bin files that are loaded inside the javascript
# !tensorflowjs_converter \
--input_format=keras_saved_model \
/content/model \
/content/jsmodel
# Out:
# 2020-06-23 03:43:31.331539: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-06-23 03:43:31.335505: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-06-23 03:43:31.335717: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x27d6bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-06-23 03:43:31.335752: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
